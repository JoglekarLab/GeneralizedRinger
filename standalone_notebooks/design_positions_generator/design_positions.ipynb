# %%
from pyrosetta import *
from pyrosetta.rosetta.core.select.residue_selector import InterGroupInterfaceByVectorSelector, ChainSelector, OrResidueSelector, NotResidueSelector
import pandas as pd
import argparse
import os
from geometry_functions import *
init()
# Out:
# PyRosetta-4 2023 [Rosetta PyRosetta4.conda.linux.cxx11thread.serialization.CentOS.python311.Release 2023.27+release.e3ce6ea9faf661ae8fa769511e2a9b8596417e58 2023-07-07T12:00:46] retrieved from: http://www.pyrosetta.org
# (C) Copyright Rosetta Commons Member Institutions. Created in JHU by Sergey Lyskov and PyRosetta Team.
# core.init: Checking for fconfig files in pwd and ./rosetta/flags
# core.init: Rosetta version: PyRosetta4.conda.linux.cxx11thread.serialization.CentOS.python311.Release r353 2023.27+release.e3ce6ea e3ce6ea9faf661ae8fa769511e2a9b8596417e58 http://www.pyrosetta.org 2023-07-07T12:00:46
# core.init: command: PyRosetta -ex1 -ex2aro -database /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/pyrosetta/database
# basic.random.init_random_generator: 'RNG device' seed mode, using '/dev/urandom', seed=-1901301938 seed_offset=0 real_seed=-1901301938 thread_index=0
# basic.random.init_random_generator: RandomGenerator:init: Normal mode, seed=-1901301938 RG_type=mt19937

# %%
def group_selector (chains):
    sel = ChainSelector(chains[0])
    for ch in chains[1:]:
        sel = OrResidueSelector(sel, ChainSelector(ch))
    return sel

def run_design_positions_generator (interface, fixed_chains, CB_DISTANCE, EXTENDED_DESIGN, MAX_DISTANCE, PDB_DIR): 
    if EXTENDED_DESIGN and MAX_DISTANCE is None:
        raise ValueError("--extended_design requires MAX_DISTANCE to be set (default=12 Å)")

    grp1_str, grp2_str = interface.split('_', 1)
    GROUP1 = list(grp1_str)
    GROUP2 = list(grp2_str)
    FIXED_CHAINS = [x.strip() for x in fixed_chains.split(',')]

    cutoff = MAX_DISTANCE if EXTENDED_DESIGN else CB_DISTANCE
    mode   = "extended interface (C alpha distance)" if EXTENDED_DESIGN else "interface (C beta distance)"
    print(f"Mode = {mode}, cutoff = {cutoff:.1f} Å")
    print(f"Designing interface between {GROUP1} and {GROUP2}, keeping {FIXED_CHAINS} fixed")

    if not EXTENDED_DESIGN:
        print ("Designing residues at interface only")
        files = [f.path for f in os.scandir(PDB_DIR) if f.is_file() and f.path.endswith('.pdb')]
        for file in files:
            print (f'Processing {file}')
            pose = pose_from_pdb(file)
            start_pose = Pose()
            start_pose.assign(pose)

            sel1 = group_selector(GROUP1)
            sel2 = group_selector(GROUP2)

            interface_selector = InterGroupInterfaceByVectorSelector(sel1, sel2)
            interface_selector.cb_dist_cut(CB_DISTANCE)
            not_interface_selector = NotResidueSelector(interface_selector)
            interface_residues = interface_selector.apply(pose) # Boolean vector

            # Map the chain to the index of where it begins
            chain_map = {}
            for i in range(1, pose.num_chains()+1):
                ch = pose.pdb_info().chain(pose.chain_begin(i))
                chain_map[ch] = pose.chain_begin(i)
            print(f"Chain begin index: {chain_map}")

            # interface_residues_dict of designable residues
            interface_residues_dict = {
                **{c: [] for c in GROUP1}, # ** operator unpacks a dict into key:value
                **{c: [] for c in GROUP2}
                } # All unpacked key:values are merged

            for chain in interface_residues_dict.keys():
                if chain in FIXED_CHAINS:
                    continue
                ires = [str(i-chain_map[chain] + 1) for i in range(1, pose.size() + 1) if interface_residues[i] and pose.pdb_info().chain(i) == str(chain)]
                interface_residues_dict[chain] = ires

            PDB_NAME = os.path.basename(file).replace(".pdb", "")
            with open(f"{PDB_DIR}/{PDB_NAME}_design_residues.txt", "w") as f:
                f.write(" ".join(interface_residues_dict.keys())) # e.g. f.write("A B C D")
                f.write("\n")

                residue_strings = []
                for chain in interface_residues_dict.keys():
                    residue_strings.append(" ".join(interface_residues_dict[chain])) if interface_residues_dict[chain] else residue_strings.append("")
                f.write(", ".join(residue_strings))


    if EXTENDED_DESIGN:
        
        print("************ Make sure your chain numbering starts with 1!!!!!!! ************")

        print ("Designing residues at interface and nearby - using c alpha distance as cutoff")
        files = [f.path for f in os.scandir(PDB_DIR) if f.is_file() and f.path.endswith('.pdb')]
        for file in files:
            print (f'Processing {file}')
            PDB_NAME = os.path.basename(file).replace(".pdb", "")
            pairs_to_omit = (
                list(permutations(GROUP1, 2)) +
                list(permutations(GROUP2, 2))
            )
            _, interface_contacts = analyze_interface (file, min_distance=1, max_distance=MAX_DISTANCE, omit_chain_pairs=pairs_to_omit)
            interface_residues_dict = { c: [] for c in (GROUP1 + GROUP2) }

            for chain in interface_residues_dict:
                if chain in FIXED_CHAINS:
                    continue

                interactions = set()
                for other_chain in (GROUP1 + GROUP2):
                    if other_chain == chain:
                        continue
                    cc1 = chain + other_chain
                    cc2 = other_chain + chain
                    interactions |= interface_contacts.get(cc1, {}).get(chain, set())
                    interactions |= interface_contacts.get(cc2, {}).get(chain, set())
                interface_residues_dict[chain] = [i+1 for i in interactions]

            print (interface_residues_dict)
            with open(f"{PDB_DIR}/{PDB_NAME}_design_residues.txt", "w") as f:
                f.write(" ".join(interface_residues_dict.keys()))
                f.write("\n")

                residue_strings = []
                for c in interface_residues_dict:
                    residue_strings.append(" ".join(str(i) for i in interface_residues_dict[c]))

                f.write(", ".join(residue_strings))

# %%
MAX_DISTANCE = 8.5
CB_DISTANCE = 7
EXTENDED_DESIGN = True
interface = "A_BC"
PDB_DIR = "input_pdbs"
fixed_chains = "C"

run_design_positions_generator (interface, fixed_chains, CB_DISTANCE, EXTENDED_DESIGN, MAX_DISTANCE, PDB_DIR)
# Out:
# Mode = extended interface (C alpha distance), cutoff = 8.5 Å
# Designing interface between ['A'] and ['B', 'C'], keeping ['C'] fixed
# ************ Make sure your chain numbering starts with 1!!!!!!! ************
# Designing residues at interface and nearby - using c alpha distance as cutoff
# Processing input_pdbs/8.pdb
# Analyzing PDB file 8.pdb
#
# {'A': [1, 3, 6, 7, 9, 10, 13, 14, 16, 17, 18, 20, 21, 22], 'B': [34, 35, 46, 23, 26, 27, 28, 30, 31], 'C': []}
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record '# All ' at line 4086
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record '#BEGIN' at line 4087
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'label ' at line 4088
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'weight' at line 4089
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'pose -' at line 4090
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLY:Nt' at line 4091
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLY_2 ' at line 4092
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLY_3 ' at line 4093
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLY_4 ' at line 4094
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLY_5 ' at line 4095
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLY_6 ' at line 4096
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLY_7 ' at line 4097
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLY_8 ' at line 4098
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLY_9 ' at line 4099
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLY_10' at line 4100
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLY_11' at line 4101
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLY_12' at line 4102
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLY_13' at line 4103
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLY_14' at line 4104
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLY_15' at line 4105
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLY_16' at line 4106
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLY_17' at line 4107
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLY_18' at line 4108
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLY_19' at line 4109
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLY_20' at line 4110
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLY_21' at line 4111
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLY_22' at line 4112
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLY_23' at line 4113
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLY:Ct' at line 4114
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'SER:Nt' at line 4115
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'SER_26' at line 4116
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LYS_27' at line 4117
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLU_28' at line 4118
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'VAL_29' at line 4119
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ALA_30' at line 4120
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLU_31' at line 4121
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LEU_32' at line 4122
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LYS_33' at line 4123
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LYS_34' at line 4124
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLN_35' at line 4125
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'VAL_36' at line 4126
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLU_37' at line 4127
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'SER_38' at line 4128
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ALA_39' at line 4129
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLU_40' at line 4130
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LEU_41' at line 4131
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LYS_42' at line 4132
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ASN_43' at line 4133
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLN_44' at line 4134
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ARG_45' at line 4135
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LEU_46' at line 4136
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LYS_47' at line 4137
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLU_48' at line 4138
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'VAL_49' at line 4139
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'PHE_50' at line 4140
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLN_51' at line 4141
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'THR_52' at line 4142
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LYS_53' at line 4143
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ILE_54' at line 4144
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLN_55' at line 4145
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLU_56' at line 4146
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'PHE_57' at line 4147
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ARG_58' at line 4148
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LYS_59' at line 4149
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ALA_60' at line 4150
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'CYS_61' at line 4151
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'TYR_62' at line 4152
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'THR_63' at line 4153
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LEU_64' at line 4154
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'THR_65' at line 4155
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLY_66' at line 4156
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'TYR_67' at line 4157
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLN_68' at line 4158
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ILE_69' at line 4159
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ASP_70' at line 4160
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ILE_71' at line 4161
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'THR_72' at line 4162
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'THR_73' at line 4163
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLU_74' at line 4164
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ASN_75' at line 4165
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLN_76' at line 4166
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'TYR_77' at line 4167
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ARG_78' at line 4168
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LEU_79' at line 4169
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'THR_80' at line 4170
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'SER_81' at line 4171
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LEU_82' at line 4172
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'TYR_83' at line 4173
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ALA_84' at line 4174
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLU_85' at line 4175
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'HIS_D_' at line 4176
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'PRO_87' at line 4177
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLY_88' at line 4178
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ASP_89' at line 4179
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'CYS_90' at line 4180
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LEU_91' at line 4181
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ILE_92' at line 4182
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'PHE_93' at line 4183
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LYS_94' at line 4184
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ALA_95' at line 4185
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'THR_96' at line 4186
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'SER_97' at line 4187
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'PRO_98' at line 4188
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'SER_99' at line 4189
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLY_10' at line 4190
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'SER_10' at line 4191
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LYS_10' at line 4192
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'MET_10' at line 4193
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLN_10' at line 4194
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LEU_10' at line 4195
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LEU_10' at line 4196
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLU_10' at line 4197
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'THR_10' at line 4198
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLU_10' at line 4199
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'PHE_11' at line 4200
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'SER_11' at line 4201
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'HIS_11' at line 4202
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'THR_11' at line 4203
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'VAL_11' at line 4204
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLY_11' at line 4205
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLU_11' at line 4206
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LEU_11' at line 4207
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ILE_11' at line 4208
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLU_11' at line 4209
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'VAL_12' at line 4210
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'HIS_D_' at line 4211
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LEU_12' at line 4212
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ARG_12' at line 4213
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ARG_12' at line 4214
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLN_12' at line 4215
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ASP_12' at line 4216
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'SER_12' at line 4217
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ILE_12' at line 4218
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'PRO_12' at line 4219
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ALA_13' at line 4220
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'PHE_13' at line 4221
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LEU_13' at line 4222
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'SER_13' at line 4223
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'SER_13' at line 4224
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LEU_13' at line 4225
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'THR_13' at line 4226
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LEU_13' at line 4227
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLU_13' at line 4228
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LEU_13' at line 4229
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'PHE_14' at line 4230
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'SER_14' at line 4231
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ARG_14' at line 4232
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLN_14' at line 4233
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'THR_14' at line 4234
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'VAL_14' at line 4235
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ALA_14' at line 4236
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'VAL_14' at line 4237
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'SER_14' at line 4238
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LYS_14' at line 4239
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLU_15' at line 4240
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'VAL_15' at line 4241
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ALA_15' at line 4242
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLU_15' at line 4243
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LEU_15' at line 4244
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LYS_15' at line 4245
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LYS_15' at line 4246
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLN_15' at line 4247
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'VAL_15' at line 4248
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLU_15' at line 4249
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'SER_16' at line 4250
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ALA_16' at line 4251
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLU_16' at line 4252
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LEU_16' at line 4253
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LYS_16' at line 4254
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ASN_16' at line 4255
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLN_16' at line 4256
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ARG_16' at line 4257
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LEU_16' at line 4258
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LYS_16' at line 4259
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLU_17' at line 4260
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'VAL_17' at line 4261
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'PHE_17' at line 4262
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLN_17' at line 4263
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'THR_17' at line 4264
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LYS_17' at line 4265
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ILE_17' at line 4266
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLN_17' at line 4267
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLU_17' at line 4268
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'PHE_17' at line 4269
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ARG_18' at line 4270
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LYS_18' at line 4271
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ALA_18' at line 4272
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'CYS_18' at line 4273
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'TYR_18' at line 4274
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'THR_18' at line 4275
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LEU_18' at line 4276
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'THR_18' at line 4277
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLY_18' at line 4278
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'TYR_18' at line 4279
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLN_19' at line 4280
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ILE_19' at line 4281
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ASP_19' at line 4282
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ILE_19' at line 4283
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'THR_19' at line 4284
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'THR_19' at line 4285
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLU_19' at line 4286
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ASN_19' at line 4287
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLN_19' at line 4288
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'TYR_19' at line 4289
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ARG_20' at line 4290
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LEU_20' at line 4291
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'THR_20' at line 4292
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'SER_20' at line 4293
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LEU_20' at line 4294
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'TYR_20' at line 4295
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ALA_20' at line 4296
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLU_20' at line 4297
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'HIS_20' at line 4298
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'PRO_20' at line 4299
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLY_21' at line 4300
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ASP_21' at line 4301
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'CYS_21' at line 4302
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LEU_21' at line 4303
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ILE_21' at line 4304
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'PHE_21' at line 4305
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LYS_21' at line 4306
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ALA_21' at line 4307
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'THR_21' at line 4308
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'SER_21' at line 4309
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LYS_22' at line 4310
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'MET_22' at line 4311
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLN_22' at line 4312
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LEU_22' at line 4313
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LEU_22' at line 4314
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLU_22' at line 4315
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'THR_22' at line 4316
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLU_22' at line 4317
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'PHE_22' at line 4318
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'SER_22' at line 4319
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'HIS_23' at line 4320
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'THR_23' at line 4321
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'VAL_23' at line 4322
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLY_23' at line 4323
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLU_23' at line 4324
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LEU_23' at line 4325
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ILE_23' at line 4326
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLU_23' at line 4327
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'VAL_23' at line 4328
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'HIS_D_' at line 4329
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LEU_24' at line 4330
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ARG_24' at line 4331
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ARG_24' at line 4332
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLN_24' at line 4333
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ASP_24' at line 4334
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'SER_24' at line 4335
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ILE_24' at line 4336
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'PRO_24' at line 4337
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ALA_24' at line 4338
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'PHE_24' at line 4339
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LEU_25' at line 4340
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'SER_25' at line 4341
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'SER_25' at line 4342
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LEU_25' at line 4343
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'THR_25' at line 4344
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LEU_25' at line 4345
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLU_25' at line 4346
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'LEU_25' at line 4347
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'PHE_25' at line 4348
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'SER_25' at line 4349
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ARG_26' at line 4350
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'GLN_26' at line 4351
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'THR_26' at line 4352
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'VAL_26' at line 4353
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record 'ALA:Ct' at line 4354
#   warnings.warn(
# /home/linamp/miniconda3/envs/myenv_gl/envs/rosetta_env/lib/python3.11/site-packages/Bio/PDB/PDBParser.py:388: PDBConstructionWarning: Ignoring unrecognized record '#END_P' at line 4355
#   warnings.warn(

# %% [markdown]
# #### Check selected positions for design

# %%
from Bio.PDB import PDBParser, PDBIO
import os

design_positions_file = "input_pdbs/8_design_residues.txt"
basename = os.path.basename(design_positions_file).replace("_design_residues.txt", "")
pdb_file    = os.path.join(os.path.dirname(design_positions_file), f"{basename}.pdb")
output_file = os.path.join(os.path.dirname(design_positions_file),
                           f"{basename}_selection_as_bfactor.pdb")

with open(design_positions_file) as f:
    chains = f.readline().split()
    lists  = [seg.strip() for seg in f.readline().split(',')]
design_map = {}
for ch, seg in zip(chains, lists):
    if seg:
        design_map[ch] = [int(x) for x in seg.split()]
    else:
        design_map[ch] = []

parser = PDBParser(QUIET=True)
structure = parser.get_structure(basename, pdb_file)

for model in structure:
    for chain in model:
        chID = chain.id
        residues = list(chain)  
        first_residue_in_chain = residues[0].id[1]
        for residue in residues:
            resnum_pdb = residue.id[1]
            resnum = resnum_pdb - first_residue_in_chain + 1
            is_design = (resnum in design_map.get(chID, []))
            bval = 100.0 if is_design else 0.0
            for atom in residue:
                atom.set_bfactor(bval)

io = PDBIO()
io.set_structure(structure)
io.save(output_file)

# To color it, in pymol use: spectrum b, lightblue red, minimum=0, maximum=100
